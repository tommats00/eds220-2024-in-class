# %% [markdown]
# # CSV to `GeoDataFrame`
#
# Let's start importing packages and updating viewing options:

# %%
import os

import pandas as pd
from pandas.api.types import is_string_dtype, is_numeric_dtype
import geopandas as gpd
import matplotlib.pyplot as plt


# Display all columns when looking at dataframes
pd.set_option("display.max.columns", None)

# %%
# Import power plants data
URL = 'https://raw.githubusercontent.com/carmengg/eds-220-book/refs/heads/main/data/power_plants_epsg4269.csv'
power_plants = pd.read_csv(URL)

# Simpify column names
power_plants.columns = power_plants.columns.str.lower()

# Drop first column
power_plants = power_plants.drop(columns='unnamed: 0')

power_plants.head(3)
# Out:
#   objectid plant_code    plant_name utility_id  \
# 0    11570          1    Sand Point      63560
# 1    11571          2  Bankhead Dam        195
# 2    11572          3         Barry        195
#
#                      utility_name       sector_name       street_address  \
# 0  TDX Sand Point Generating, LLC  Electric Utility  100 Power Plant Way
# 1                Alabama Power Co  Electric Utility   19001 Lock 17 Road
# 2                Alabama Power Co  Electric Utility     North Highway 43
#
#          city          county    state      zip     primsource  \
# 0  Sand Point  Aleutians East   Alaska  99661.0      petroleum
# 1   Northport      Tuscaloosa  Alabama  35476.0  hydroelectric
# 2       Bucks          Mobile  Alabama  36512.0    natural gas
#
#                                  source_desc  \
# 0          Petroleum = 1.3 MW, Wind = 0.4 MW
# 1                      Hydroelectric = 53 MW
# 2  Coal = 1118.5 MW, Natural Gas = 1296.2 MW
#
# ...

# %%
# Create points from latitude and longitude
points = gpd.points_from_xy(power_plants.longitude, 
                            power_plants.latitude)

# Create geodataframe
power_plants = gpd.GeoDataFrame(power_plants,    # Data
                                geometry=points, # Specify geometry column
                                crs='EPSG:4269'  # Specify CRS
                                )

# %%
power_plants.plot()
# Out:
# <Axes: >

# %% [markdown]
# # f-strings

# %%
print('CRS: ', power_plants.crs)
# Out:
# CRS:  EPSG:4269

# %% [markdown]
# Another populat way to mix variables and
#
# The simplest syntax:
# ```python
# f"some text {replace}"
# ```
# where `replace` can be a variable, na expression a function or method call.
# Example:

# %%
# Check what is the ellipsoid
f"ellipsoid: {power_plants.crs.ellipsoid}"
# Out:
# 'ellipsoid: GRS 1980'

# %%
# Use f-strings inside the print function
print(f"datum: {power_plants.crs.datum}")
# Out:
# datum: North American Datum 1983

# %% [markdown]
# Advantages of using f-strings: a lot of customization for formatting output.

# %%
# Set the lab width to 25 characters, aligning the answers
print(f"{'Is the CRS geographic?:':<25} {power_plants.crs.is_geographic}")

print(f"{'Is the CRS projected?:':<25} {power_plants.crs.is_projected}")
# Out:
# Is the CRS geographic?:   True
# Is the CRS projected?:    False

# %% [markdown]
# ## Import shapefile

# %%
os.getcwd()
# Out:
# '/Users/tbg/MEDS/eds-220/eds220-2024-in-class'

# %%
# Create absolute file path from the root directory to out file data in the server
fp = os.path.join('/', 
                  'courses', 
                  'EDS220', 
                  'data', 
                  'tl_2022_us_state', 
                  'tl_2022_us_state.shp')

states = gpd.read_file(fp)

# Simiplify column names
states.columns = states.columns.str.lower()

states.head(3)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/anaconda3/envs/eds220-env/share/proj failed
#   region division statefp   statens geoid stusps           name lsad  mtfcc  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
#
#   funcstat         aland       awater     intptlat      intptlon  \
# 0        A   62266456923    489045863  +38.6472854  -080.6183274
# 1        A  138962819934  45971472526  +28.3989775  -082.5143005
# 2        A  143778515726   6216539665  +40.1028754  -089.1526108
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# 1  MULTIPOLYGON (((-83.10874 24.62949, -83.10711 ...
# 2  POLYGON ((-87.89243 38.28285, -87.89334 38.282...

# %%
print(states.crs)
states.plot()
# Out:
# EPSG:4269
# <Axes: >

# %% [markdown]
# ## Using `for` loops
#
# It can be easier to work with the code as numbers instead of strings, let's update the corresponding columns in the geo-dataframe:
# `region`, `division`, `statefp`
#
# First thing, check if these are columns with strings:

# %%
print(f"region is string dtype? {is_string_dtype(states['region'])}")
print(f"division is string dtype? {is_string_dtype(states['division'])}")
print(f"statefp is string dtype? {is_string_dtype(states['statefp'])}")
# Out:
# region is string dtype? True
# division is string dtype? True
# statefp is string dtype? True

# %% [markdown]
# This is inconvenient because it repeats the same piece of code, only changing the column name.
# Instead, using a `for` loop allows to succintly print the same info:

# %%
code_cols = ['region', 'division', 'statefp']

# Check whether codes columns are strings
for column in code_cols:
    print(f"{column} is string dtype? {is_string_dtype(states[column])}")
# Out:
# region is string dtype? True
# division is string dtype? True
# statefp is string dtype? True

# %% [markdown]
# `for` loops execute a block of code a fixed number of times, iterating over a set of objects. In this case, we iterate over the list of column names.
#
# **DRY code**
#
# DRY = don't repeat yourself is a core programming principle that encourages reducing redundancy and consolidating repeated logic.
# If you need to repeat the "same" code more than twice, you probably need a `for` loop.
#
# Next, update data type of the code columns to be integeres.
# This time, we verify the data type of the column using the `is_numeric_dtype()` and `assert` statement:

# %%
# Update code columns into integers
for column in code_cols:
    states[column] = states[column].astype('int')
    assert is_numeric_dtype(states[column]) # Check conversion

# %% [markdown]
# The `assert` keyword does nothing if the expression next to it evaluates to `True`.
# If the expression evaluates to `False` then `assert` raises an `AssertionError` and stops your code from running.
# Example:

# %%
# Does nothing if statement is True
assert 2 + 2 == 4

# %%
# Raises an error if statement is False, **TESTTHAT IN R**
# assert 2 + 2 == 3

# %% [markdown]
# ## Data selection
#
# For this lesson, we want to use only the contiguous states. The `states` geo-dataframe convers a bigger extension

# %%
states.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Check-in
# - What are the unique values for region, division, or state codes in the data?
# - Which codes should we select to keep only states in the contiguous US?

# %%
states.region.unique()
states.division.unique()
states.statefp.unique()

# for column in code_cols:
#     print(f" The unique values in {states[column]} are {states[column].nunique()}")
# Out:
# array([54, 12, 17, 27, 24, 44, 16, 33, 37, 50,  9, 10, 35,  6, 34, 55, 41,
#        31, 42, 53, 22, 13,  1, 49, 39, 48,  8, 45, 40, 47, 56, 15, 38, 21,
#        78, 69, 66, 23, 36, 32,  2, 60, 26,  5, 28, 29, 30, 20, 18, 72, 46,
#        25, 51, 11, 19,  4])

# %%
# Select contiguous US states
# Can use [] or . to select the column
# the ~ says to return only the rows that are true
contiguous = states[ (states.region!=9) & (~states.statefp.isin([2,15]))]

# %%
contiguous.plot()
# Out:
# <Axes: >

# %% [markdown]
# The `~` tilde symbol is used in Python to negate a statement.
#
# ## Check-in
# Select the data in the `power_plants` data frame for the contiguous US states.

# %%
power_plants = power_plants[~power_plants.state.isin(['Puerto Rico', 'Hawaii', 'Alaska'])]

# %%
power_plants.head(3)
# Out:
#   objectid plant_code          plant_name utility_id      utility_name  \
# 1    11571          2        Bankhead Dam        195  Alabama Power Co
# 2    11572          3               Barry        195  Alabama Power Co
# 3    11573          4  Walter Bouldin Dam        195  Alabama Power Co
#
#         sector_name        street_address       city      county    state  \
# 1  Electric Utility    19001 Lock 17 Road  Northport  Tuscaloosa  Alabama
# 2  Electric Utility      North Highway 43      Bucks      Mobile  Alabama
# 3  Electric Utility  750 Bouldin Dam Road   Wetumpka      Elmore  Alabama
#
#        zip     primsource                                source_desc  \
# 1  35476.0  hydroelectric                      Hydroelectric = 53 MW
# 2  36512.0    natural gas  Coal = 1118.5 MW, Natural Gas = 1296.2 MW
# 3  36092.0  hydroelectric                   Hydroelectric = 224.1 MW
#
#                                            tech_desc  install_mw  total_mw  \
# ...

# %% [markdown]
# ## Plotting
#
# Before we plot our data, let's make sure they are in the same CRS:

# %%
contiguous.crs == power_plants.crs
# Out:
# True

# %%
fig, ax = plt.subplots(figsize=(9,5))

# Remove axis for a cleaner map
ax.axis('off')

ax.set_title('Operable electric generating plants in the contiguous US', fontsize = 15)

contiguous.plot(ax=ax,
               color = 'none',
               edgecolor='black')

# Add electric power plants colored by energy source

power_plants.plot(ax=ax,
                 column='primsource', # Color by values in this column
                 legend=True,
                 markersize=4,
                 cmap='tab20',
                 alpha=0.5,
                 legend_kwds={
                     'title':'Primary energy source',
                     'title_fontsize':'small',
                     'loc':'upper left',
                     'bbox_to_anchor':(0,0),
                     'ncol':6
                 }
                 ) 

plt.show()

# %% [markdown]
# We controlled the legend location using `loc` and `bbox_to_anchor` in the `legend_kwds`:
#
# - `loc` indicates **the corner of the legend that we want to use for placement**
# - `bbox_to_anchor` is a tuple with coordinates indicating where to place the corner specified in `loc` relative to the axes. Values between 0 and 1 are *inside* the axes.

# %% [markdown]
# ## `for` with `zip`
#
# Often, we need to iterate simultanously over two lists (or iterables).
#
# `zip()` is a Python function that allows you to combine two lists so that you can iterate over their elements in pairs.
#
# When used in a `for` loop it allows you to process elements of each list together
#
# Example:

# %%
# Iterate over a single list
numbers = [1,2,3]
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3

# %%
# Iterate over two lists in pairs using zip()
letters = ['a', 'b', 'c']
for num, letter in zip(numbers, letters):
    print(num,letter)
# Out:
# 1 a
# 2 b
# 3 c

# %% [markdown]
# Example: with `matplotlibt`
# A common situation when code gets repeated is whwen creating subplots

# %%
fig, axes = plt.subplots(nrows=1, ncols= 3, figsize=(7,3))
axes[0].set_title('This is axis 0')
axes[1].set_title('This is axis 1')
axes[2].set_title('This is axis 2')

plt.show()

# %% [markdown]
# ## Check-in
#
# Use `for` and `zip` to create the same subplots and avoid redundancy.

# %%
# fig, axes = plt.subplots(nrows=1, ncols= 3, figsize=(7,3))
# axes[0].set_title('This is axis 0')
# axes[1].set_title('This is axis 1')
# axes[2].set_title('This is axis 2')


fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(7,3))

for ax, i in zip(axes, [0,1,2]):
    ax.set_title(f"This is axis {i}")
    
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(7,3))
for i in [0,1,2]:
    axes[i].set_title(f"This is axis {i}")
    
plt.show()

# %%
power_plants.head(2)
# Out:
#   objectid plant_code    plant_name utility_id      utility_name  \
# 1    11571          2  Bankhead Dam        195  Alabama Power Co
# 2    11572          3         Barry        195  Alabama Power Co
#
#         sector_name      street_address       city      county    state  \
# 1  Electric Utility  19001 Lock 17 Road  Northport  Tuscaloosa  Alabama
# 2  Electric Utility    North Highway 43      Bucks      Mobile  Alabama
#
#        zip     primsource                                source_desc  \
# 1  35476.0  hydroelectric                      Hydroelectric = 53 MW
# 2  36512.0    natural gas  Coal = 1118.5 MW, Natural Gas = 1296.2 MW
#
#                                            tech_desc  install_mw  total_mw  \
# 1                         Conventional Hydroelectric        53.9      53.0
# 2  Conventional Steam Coal; Natural Gas Fired Com...      2569.5    2414.7
#
#    bat_mw  bio_mw  coal_mw  geo_mw  hydro_mw  hydrops_mw   ng_mw nuclear_mw  \
# ...

# %%
power_plants.plot()
# Out:
# <Axes: >

# %%
states.head(2)
# Out:
#    region  division  statefp   statens geoid stusps           name lsad  \
# 0       3         5       54  01779805    54     WV  West Virginia   00
# 1       3         5       12  00294478    12     FL        Florida   00
#
#    mtfcc funcstat         aland       awater     intptlat      intptlon  \
# 0  G4000        A   62266456923    489045863  +38.6472854  -080.6183274
# 1  G4000        A  138962819934  45971472526  +28.3989775  -082.5143005
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# 1  MULTIPOLYGON (((-83.10874 24.62949, -83.10711 ...

# %%
states.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Exercise
#
# 1. Select the power plants in California in a variable named 'ca_power_plants'.
# 2. Create a _list_ named `top_sources` with California’s top 3 electric primary sources.
# 3. Isolate the California state boundary in a variable named ca_boundary.
# 4. Recreate the following plot:

# %%
ca_power_plants = power_plants[power_plants['state'] == 'California']
ca_power_plants.head(4)
# Out:
#    objectid plant_code    plant_name utility_id  \
# 19    11589         34       Rollins      13402
# 38    11608         72  Venice Hydro      12397
# 54    11624        104  J S Eastwood      17609
# 74    11644        151       McClure      12745
#
#                            utility_name       sector_name  \
# 19           Nevada Irrigation District       IPP Non-CHP
# 38  Metropolitan Water District of S CA  Electric Utility
# 54        Southern California Edison Co  Electric Utility
# 74          Modesto Irrigation District  Electric Utility
#
#                     street_address         city       county       state  \
# 19           15531 Arrow Head Lane       Colfax       Placer  California
# 38             3815 Sepulveda Blvd  Culver City  Los Angeles  California
# 54  Hwy 168 Sierra National Forest  Shaver Lake       Fresno  California
# 74              639 S. McClure Rd.      Modesto   Stanislaus  California
#
# ...

# %%
# Create a list named top_sources with California’s top 3 electric primary sources.
top_sources = ca_power_plants.primsource.value_counts().head(3).keys().to_list()
top_sources

#### Can also do it this way ####
# ca_power_plants.primsource.value_counts().index[:3]
# Out:
# Index(['solar', 'natural gas', 'hydroelectric'], dtype='object', name='primsource')

# %%
# Isolate the California state boundary in a variable named ca_boundary.
ca_boundary = states[states.name=='California']
ca_boundary.plot()
# Out:
# <Axes: >

# %%
# Create plot
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(6,3))

for ax, source in zip(axes, top_sources):
    ca_boundary.plot(ax=ax,
                    color = 'none')
    
    # Select points for the sources
    subset = ca_power_plants[ca_power_plants.primsource == source]
    subset.plot(ax=ax, 
                markersize=0.5)
    ax.set_title(source)
    ax.axis('off')
    
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,5))

# Remove axis for a cleaner map
ax.axis('off')

ax.set_title('Operable electric generating plants in the contiguous US', fontsize = 15)

contiguous.plot(ax=ax,
               color = 'none',
               edgecolor='black')

# Add electric power plants colored by energy source

ca_power_plants.plot(ax=ax,
                 column='primsource', # Color by values in this column
                 legend=True,
                 markersize=4,
                 cmap='tab20',
                 alpha=0.5,
                 legend_kwds={
                     'title':'Primary energy source',
                     'title_fontsize':'small',
                     'loc':'upper left',
                     'bbox_to_anchor':(0,0),
                     'ncol':6
                 }
                 ) 

plt.show()

# %% [markdown]
# ## Functions
#
# **functions** in Python are blocks of resuable code designed to perform specific tasks, and make your code more modular and organized.
# The general syntax:
# ```python
# def function_name(parameter_1, ...., parameter_n):
#     """Docstring""" #####Special comment that tells what the function does#######
#     <body of the function>
#     return value # Depend on the function
# ```
#
# Examples:
# A simple function with a one-line docstring and no return values.

# %%
def greet():
    """Print a greeting message"""
    print("Hello, welcome to the class!")

# %%
greet()
# Out:
# Hello, welcome to the class!

# %% [markdown]
# **Examples 2:**
# a function with a more detailed docstring and a return value

# %%
def circle_area(radius):
    """
    Calculate the area of a circle given its radius.
    
    Args:
        radius (float): The radius of the circle
    Returns:
        float: The area of the circle, calculated as pi * radius^2
    """
    area = 3.14159 * radius ** 2
    return area

# %%
circle_area(2)
# Out:
# 12.56636

# %% [markdown]
# ## Example
#
# Going back to our power_plants data frame, let's create a function that will give us the top 3 primary energy sources for a given state.

# %%
def top3_sources(state):
    state_power_plants = power_plants[power_plants['state'] == state]
    top_sources = state_power_plants.primsource.value_counts().head(3).keys().to_list()
    return top_sources

# %%
top3_sources('New York')
# Out:
# ['solar', 'hydroelectric', 'natural gas']

# %%
top3_sources('Texas')
# Out:
# ['natural gas', 'wind', 'solar']

# %%
top3_sources('California')
# Out:
# ['solar', 'natural gas', 'hydroelectric']
